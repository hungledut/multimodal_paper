# %%
import hashlib
import io
from pathlib import Path
import pandas as pd
import requests
from bs4 import BeautifulSoup
from PIL import Image
from selenium import webdriver
import os
import urllib

# %%
def Crawler(url_tail):
   
    #create chromeoptions instance
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")
    options.add_argument("--no-sandbox")

    #provide location where chrome stores profiles
    options.add_argument(r"--user-data-dir=/home/username/.config/google-chrome")

    #provide the profile name with which we want to open browser
    options.add_argument(r'--profile-directory=Profile 3')
    
    
    driver = webdriver.Chrome(options=options)

    url = "https://www.amazon.com" + url_tail
    
    print(url)
    
    driver.get(url)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    results = []
    content = driver.page_source
    soup = BeautifulSoup(content)
    driver.quit()
    results = []
    for a in soup.findAll('div', class_ = "a-section a-spacing-medium a-spacing-top-small"):
        A = a.findAll('span', class_ = "a-list-item")
        print(A)
        results = str(A).replace( '<span class=\"a-list-item\">' , ' ').replace( '</span>' , ' ')
    print(str(results))
    return str(results)

# %%
def Crawl_Text(Links):
    Text_crawl = []
    count = 0
    for Link in Links[:,0]:
        Text_crawl.append(Crawler(Link))
        print(count)
        count = count + 1
    return Text_crawl

# %%
# categories = ["table" , "cell+phone", "laptop", "hat", "shoes" ]
# categories = ["t-shirts" , "headphones", "keyboard", "bag", "chair" ]
# categories = ["television" , "fridge", "mouse"]
# categories = ["printer","washing+machine"]
# categories = ["tablet","vacuum","lamp"]
categories = ["digital+camera","speaker","iron"]

# %%
for category in categories:
    df = pd.read_csv(category + ".csv")
    Links = df.values
    df_saved = pd.DataFrame(Crawl_Text(Links))
    df_saved.to_csv(category + "_Text"+ ".csv",index = False)
# Out:
# https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozNzcxOTA2NTMxODI1Njg3OjE3MDAzNjg4OTE6c3BfYXRmOjMwMDA1NTgwMDIxMDMwMjo6MDo6&url=%2FLenovo-GXC1D66063-510-FHD-Webcam%2Fdp%2FB09S2B2QX2%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Ddigital%2Bcamera%26qid%3D1700368891%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# ...

# %%
# import pandas as pd

# df = pd.read_csv('table.csv')
# Link_table = df.values

# %%
# Text_crawl = []
# count = 0
# for Link in Link_table[:,0]:
#     Text_crawl.append(Crawler(Link))
#     print(count)
#     count = count + 1

# %%
# df = pd.DataFrame(Text_crawl)
# df.to_csv('Text_table.csv',index = False)

# %%
# df = pd.read_csv('cellphone.csv')
# Link_cellphone = df.values

# %%
# Text_crawl = []
# count = 0
# for Link in Link_cellphone[:,0]:
#     Text_crawl.append(Crawler(Link))
#     print(count)
#     count = count + 1

# %%
# df = pd.DataFrame(Text_crawl)
# df.to_csv('Text_cellphone.csv',index = False)
